# %% [markdown]
# **<center><font size=6> Brain Tumer Detection </font></center>**

# %% [markdown]
# # <a id='intro'>1. Project Objective</a>
#
# Write Objective here

# %% [markdown]
# # <a id='imports'>2. Imports</a>

# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
from PIL import Image
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, recall_score, precision_score
import seaborn as sns
import cv2
import imutils
from tqdm import tqdm

from functools import partial

# %% [markdown]
# ## <a id='helperfunctions'> 2.1 Helper Functions</a>

# %%
def crop_imgs(set_name, target_size=(100, 100), add_pixels_value=0):
    """
    Finds the extreme points on the image, crops the rectangular out of them,
    and resizes the cropped images to the target size.
    """
    set_new = []
    for img in set_name:
        gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
        gray = cv2.GaussianBlur(gray, (5, 5), 0)

        # threshold the image, then perform a series of erosions +
        # dilations to remove any small regions of noise
        thresh = cv2.threshold(gray, 45, 255, cv2.THRESH_BINARY)[1]
        thresh = cv2.erode(thresh, None, iterations=2)
        thresh = cv2.dilate(thresh, None, iterations=2)

        # find contours in thresholded image, then grab the largest one
        cnts = cv2.findContours(thresh.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        cnts = imutils.grab_contours(cnts)
        c = max(cnts, key=cv2.contourArea)

        # find the extreme points
        extLeft = tuple(c[c[:, :, 0].argmin()][0])
        extRight = tuple(c[c[:, :, 0].argmax()][0])
        extTop = tuple(c[c[:, :, 1].argmin()][0])
        extBot = tuple(c[c[:, :, 1].argmax()][0])

        ADD_PIXELS = add_pixels_value
        new_img = img[extTop[1]-ADD_PIXELS:extBot[1]+ADD_PIXELS, extLeft[0]-ADD_PIXELS:extRight[0]+ADD_PIXELS].copy()
        new_img = cv2.resize(new_img, target_size)  # Redimensionar a imagem cortada
        set_new.append(new_img)

    return np.array(set_new)

def load_data(dir_path, img_size=(100, 100)):
    """
    Load resized images as np.arrays to workspace
    """
    X = []
    y = []
    i = 0
    labels = dict()
    for path in tqdm(sorted(os.listdir(dir_path))):
        if not path.startswith('.'):
            labels[i] = path
            for file in os.listdir(os.path.join(dir_path, path)):
                if not file.startswith('.'):
                    img = cv2.imread(os.path.join(dir_path, path, file))
                    img = cv2.resize(img, img_size)  # Redimensionar a imagem
                    X.append(img)
                    y.append(i)
            i += 1
    X = np.array(X)
    y = np.array(y)
    print(f'{len(X)} images loaded from {dir_path} directory.')
    return X, y, labels

def load_dfs_imgs(data_dir):


    filepaths = []
    labels = []

    folds = os.listdir(data_dir)
    for fold in folds:
        foldpath = os.path.join(data_dir, fold)
        filelist = os.listdir(foldpath)
        for file in filelist:
            fpath = os.path.join(foldpath, file)

            filepaths.append(fpath)
            labels.append(fold)

    # Concatenate data paths with labels into one dataframe
    Fseries = pd.Series(filepaths, name= 'filepaths')
    Lseries = pd.Series(labels, name='labels')
    df = pd.concat([Fseries, Lseries], axis= 1)
    
    return df


def plot_samples(X, y, labels_dict, n=50):
    """
    Creates a gridplot for desired number of images (n) from the specified set
    """
    for index in range(len(labels_dict)):
        imgs = X[np.argwhere(y == index)][:n]
        j = 10
        i = int(n/j)

        plt.figure(figsize=(15,6))
        c = 1
        for img in imgs:
            plt.subplot(i,j,c)
            plt.imshow(img[0])

            plt.xticks([])
            plt.yticks([])
            c += 1
        plt.suptitle('Tumor: {}'.format(labels_dict[index]))
        plt.show()
        
def save_new_images(x_set, y_set, folder_name):
    for i, (img, imclass) in enumerate(zip(x_set, y_set)):
        if imclass == 0:
            save_path = os.path.join(folder_name, 'NO', f'{i}.jpg')
        else:
            save_path = os.path.join(folder_name, 'YES', f'{i}.jpg')
        cv2.imwrite(save_path, img)

# %% [markdown]
# # <a id='loadrawimages'>3. Data Import</a>

# %%
# load all images
path = 'C:/Users/edils/repos/brain_tumor_detection/data/'
img_size = (224,244)

X_train, y_train, labels = load_data(path, img_size)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[91], line 5
#       2 path = 'C:/Users/edils/repos/brain_tumor_detection/data/'
#       3 img_size = (224,244)
# ----> 5 X_train, y_train, labels = load_data(path, img_size)
#
# Cell In[89], line 49, in load_data(dir_path, img_size)
#      47 if not file.startswith('.'):
#      48     img = cv2.imread(os.path.join(dir_path, path, file))
# ---> 49     img = cv2.resize(img, img_size)  # Redimensionar a imagem
#      50     X.append(img)
#      51     y.append(i)
#
# error: OpenCV(4.8.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\resize.cpp:4062: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'

# %% [markdown]
# ## <a id='cropimages'>3.1 Crop Images</a>

# %%
# Crop Black parts of each image
X_train_crop = crop_imgs(set_name=X_train)

# %%
plot_samples(X_train_crop, y_train, labels, 20)

# %% [markdown]
# ## <a id='savecropedimages'>3.2 Save Croped Images</a>

# %%
folder_name = 'C:/Users/edils/repos/brain_tumor_detection/data/cropped/'
if not os.path.exists(folder_name):
    os.makedirs(folder_name)

save_new_images(X_train_crop, y_train, folder_name = 'C:/Users/edils/repos/brain_tumor_detection/data/cropped/')

# %% [markdown]
# # Load Cropped Images for training

# %%
df = load_dfs_imgs(data_dir='C:/Users/edils/repos/brain_tumor_detection/data/cropped/')

# %%
df
# Out:
#                                              filepaths labels
# 0    C:/Users/edils/repos/brain_tumor_detection/dat...     NO
# 1    C:/Users/edils/repos/brain_tumor_detection/dat...     NO
# 2    C:/Users/edils/repos/brain_tumor_detection/dat...     NO
# 3    C:/Users/edils/repos/brain_tumor_detection/dat...     NO
# 4    C:/Users/edils/repos/brain_tumor_detection/dat...     NO
# ..                                                 ...    ...
# 248  C:/Users/edils/repos/brain_tumor_detection/dat...    YES
# 249  C:/Users/edils/repos/brain_tumor_detection/dat...    YES
# 250  C:/Users/edils/repos/brain_tumor_detection/dat...    YES
# 251  C:/Users/edils/repos/brain_tumor_detection/dat...    YES
# 252  C:/Users/edils/repos/brain_tumor_detection/dat...    YES
#
# [253 rows x 2 columns]

# %% [markdown]
# # Split Train-Val-Test

# %%
X_train, X_val = train_test_split(df, test_size=0.2, shuffle=True, random_state=42)
X_train, X_test = train_test_split(X_train, test_size=0.1, shuffle=True, random_state=42)

# %%
#image size
batch_size=16
img_size = (150,150)
channels=3
img_shape = (img_size[0], img_size[1], channels)

tr_gen = ImageDataGenerator(rotation_range=15,
    width_shift_range=0.05,
    height_shift_range=0.05,
    shear_range=0.05,
    brightness_range=[0.1, 1.5],
    horizontal_flip=True,
    vertical_flip=True)

ts_gen = ImageDataGenerator()

train_gen = tr_gen.flow_from_dataframe(X_train, 
                                       x_col='filepaths', 
                                       y_col='labels',
                                       rescale=1./255,
                                       target_size=img_size,
                                       class_mode='categorical',
                                       color_mode='rgb',
                                       shuffle=True,
                                       batch_size=batch_size)

val_gen = tr_gen.flow_from_dataframe(X_val, 
                                       x_col='filepaths', 
                                       y_col='labels',
                                       rescale=1./255,
                                       target_size=img_size,
                                       class_mode='categorical',
                                       color_mode='rgb',
                                       shuffle=True,
                                       batch_size=batch_size)

test_gen = tr_gen.flow_from_dataframe(X_test, 
                                       x_col='filepaths', 
                                       y_col='labels',
                                       rescale=1./255,
                                       target_size=img_size,
                                       class_mode='categorical',
                                       color_mode='rgb',
                                       shuffle=False,
                                       batch_size=batch_size)
# Out:
# Found 181 validated image filenames belonging to 2 classes.
# Found 51 validated image filenames belonging to 2 classes.
# Found 21 validated image filenames belonging to 2 classes.

# %%
#Show sample data
g_dict = train_gen.class_indices      # defines dictionary {'class': index}
classes = list(g_dict.keys())       # defines list of dictionary's kays (classes), classes names : string
images, labels = next(train_gen)      # get a batch size samples from the generator

plt.figure(figsize= (20, 20))

for i in range(16):
    plt.subplot(4, 4, i + 1)
    image = images[i] / 255       # scales data to range (0 - 255)
    plt.imshow(image)
    index = np.argmax(labels[i])  # get image index
    class_name = classes[index]   # get class of image
    plt.title(class_name, color= 'blue', fontsize= 12)
    plt.axis('off')
plt.show()

# %%
def create_model():
    model = tf.keras.Sequential([
        tf.keras.layers.Rescaling(1/255, input_shape=(150, 150, 3)),
        tf.keras.layers.Conv2D(8, (2,2), activation='relu', kernel_initializer='he_normal'),
        tf.keras.layers.MaxPooling2D(2,2),
        tf.keras.layers.Conv2D(16, (3,3), activation='relu', kernel_initializer='he_normal'),
        tf.keras.layers.MaxPooling2D(2,2),
        tf.keras.layers.Conv2D(32, (3,3), activation='relu', kernel_initializer='he_normal'),
        tf.keras.layers.MaxPooling2D(2,2),
        tf.keras.layers.Flatten(),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dense(32, activation='relu', kernel_initializer='he_normal'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dense(16, activation='relu', kernel_initializer='he_normal'),
        tf.keras.layers.Dense(2, activation='softmax')  # Alteração na camada de saída
    ])
    
    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',  # Alteração na função de perda
                  metrics=['accuracy'])
    return model

# %%
model = create_model()

# %%
model.summary()
# Out:
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_14 (Rescaling)    (None, 150, 150, 3)       0
#
#  conv2d_35 (Conv2D)          (None, 149, 149, 8)       104
#
#  max_pooling2d_35 (MaxPooli  (None, 74, 74, 8)         0
#  ng2D)
#
#  conv2d_36 (Conv2D)          (None, 72, 72, 16)        1168
#
#  max_pooling2d_36 (MaxPooli  (None, 36, 36, 16)        0
#  ng2D)
#
#  conv2d_37 (Conv2D)          (None, 34, 34, 32)        4640
#
#  max_pooling2d_37 (MaxPooli  (None, 17, 17, 32)        0
#  ng2D)
#
#  flatten_14 (Flatten)        (None, 9248)              0
#
#  batch_normalization_2 (Bat  (None, 9248)              36992
#  chNormalization)
#
#  dense_42 (Dense)            (None, 32)                295968
#
#  batch_normalization_3 (Bat  (None, 32)                128
#  chNormalization)
#
#  dense_43 (Dense)            (None, 16)                528
#
#  dense_44 (Dense)            (None, 2)                 34
#
# =================================================================
# Total params: 339562 (1.30 MB)
# Trainable params: 321002 (1.22 MB)
# Non-trainable params: 18560 (72.50 KB)
# _________________________________________________________________

# %%
epochs=30
batch_size=8
early_stopping = EarlyStopping(
                monitor='val_accuracy', 
                mode='max',
                patience=10,
                restore_best_weights=True
)


history = model.fit(train_gen, validation_data=val_gen, epochs=epochs, callbacks=[early_stopping])
# Out:
# Epoch 1/30
# 12/12 [==============================] - 3s 146ms/step - loss: 0.9094 - accuracy: 0.5746 - val_loss: 1.8331 - val_accuracy: 0.6078
# Epoch 2/30
# 12/12 [==============================] - 2s 131ms/step - loss: 0.6915 - accuracy: 0.5746 - val_loss: 1.1392 - val_accuracy: 0.6078
# Epoch 3/30
# 12/12 [==============================] - 2s 131ms/step - loss: 0.6400 - accuracy: 0.6354 - val_loss: 0.6625 - val_accuracy: 0.6275
# Epoch 4/30
# 12/12 [==============================] - 2s 130ms/step - loss: 0.6070 - accuracy: 0.6740 - val_loss: 0.7072 - val_accuracy: 0.6275
# Epoch 5/30
# 12/12 [==============================] - 1s 123ms/step - loss: 0.5729 - accuracy: 0.7293 - val_loss: 0.6492 - val_accuracy: 0.6471
# Epoch 6/30
# 12/12 [==============================] - 2s 126ms/step - loss: 0.5372 - accuracy: 0.7403 - val_loss: 0.6993 - val_accuracy: 0.6078
# Epoch 7/30
# 12/12 [==============================] - 2s 126ms/step - loss: 0.5644 - accuracy: 0.7348 - val_loss: 0.6359 - val_accuracy: 0.6667
# Epoch 8/30
# 12/12 [==============================] - 2s 125ms/step - loss: 0.5544 - accuracy: 0.7127 - val_loss: 0.6357 - val_accuracy: 0.7059
# Epoch 9/30
# 12/12 [==============================] - 2s 135ms/step - loss: 0.5490 - accuracy: 0.7624 - val_loss: 0.6188 - val_accuracy: 0.6471
# Epoch 10/30
# 12/12 [==============================] - 2s 125ms/step - loss: 0.4735 - accuracy: 0.7790 - val_loss: 0.6481 - val_accuracy: 0.6471
# Epoch 11/30
# 12/12 [==============================] - 2s 135ms/step - loss: 0.4872 - accuracy: 0.7459 - val_loss: 0.6319 - val_accuracy: 0.6667
# Epoch 12/30
# 12/12 [==============================] - 2s 129ms/step - loss: 0.5643 - accuracy: 0.7569 - val_loss: 0.6670 - val_accuracy: 0.6078
# Epoch 13/30
# 12/12 [==============================] - 2s 132ms/step - loss: 0.5094 - accuracy: 0.7624 - val_loss: 0.6076 - val_accuracy: 0.6863
# Epoch 14/30
# 12/12 [==============================] - 2s 130ms/step - loss: 0.4983 - accuracy: 0.7569 - val_loss: 0.5694 - val_accuracy: 0.6471
# Epoch 15/30
# 12/12 [==============================] - 2s 127ms/step - loss: 0.5464 - accuracy: 0.7293 - val_loss: 0.5821 - val_accuracy: 0.6863
# Epoch 16/30
# 12/12 [==============================] - 2s 125ms/step - loss: 0.5282 - accuracy: 0.7403 - val_loss: 0.5863 - val_accuracy: 0.7059
# Epoch 17/30
# 12/12 [==============================] - 2s 124ms/step - loss: 0.5686 - accuracy: 0.6851 - val_loss: 0.6520 - val_accuracy: 0.6275
# Epoch 18/30
# 12/12 [==============================] - 2s 127ms/step - loss: 0.5255 - accuracy: 0.7182 - val_loss: 0.6546 - val_accuracy: 0.5882

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs =[*range(18)]

plt.plot(epochs, loss, 'r')
plt.plot(epochs, val_loss, 'b')
plt.title('Training and validation loss')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(["Loss", "Validation Loss"])
plt.show()

# %%
model.evaluate(test_gen)
# Out:
# 2/2 [==============================] - 0s 26ms/step - loss: 0.5937 - accuracy: 0.7619
# [0.5937207937240601, 0.761904776096344]

# %%
y_pred = model.predict(test_gen)
# Out:
# 2/2 [==============================] - 0s 26ms/step

# %%
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = test_gen.labels
confusion_mtx = confusion_matrix(y_true, y_pred_classes)

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_mtx, annot=True, fmt='d', cmap='Blues', 
            xticklabels=classes, yticklabels=classes)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %%
recall_score(y_true, y_pred_classes)
# Out:
# 0.8666666666666667

# %%
precision_score(y_true, y_pred_classes)
# Out:
# 0.7894736842105263
